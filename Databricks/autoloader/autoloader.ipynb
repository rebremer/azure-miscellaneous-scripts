# %%
from pyspark.sql.types import StructType

par_container_name = "autoloader"

userSchema = StructType().add("name", "string").add("age", "string")
#csvDF = spark.readStream.format("cloudFiles").schema(userSchema).load("/mnt/" + par_container_name)    # Equivalent to format("csv").load("/path/to/directory")

df = spark.readStream.format("cloudFiles").schema(userSchema).option("cloudFiles.format", "csv").load("/mnt/" + par_container_name)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>name</th><th>age</th></tr></thead><tbody><tr><td>Rene</td><td> 40</td></tr><tr><td>Thom</td><td> 10</td></tr><tr><td>Marlous</td><td> 39</td></tr><tr><td>Krijn</td><td> 8</td></tr><tr><td>Stef</td><td> 6</td></tr></tbody></table></div>

# %%
windowedCounts = df.groupBy(df.name).count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(windowedCounts)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>name</th><th>count</th></tr></thead><tbody><tr><td>Thom</td><td>1</td></tr><tr><td>Krijn</td><td>1</td></tr><tr><td>Stef</td><td>1</td></tr><tr><td>Marlous</td><td>1</td></tr><tr><td>Rene</td><td>1</td></tr></tbody></table></div>
