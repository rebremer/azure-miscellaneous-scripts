# %%
# Read a Delta table from OneLake using the high-concurrency Spark session.
df = spark.read.format("delta").load(
    "abfss://d645b0ed-b64d-4fa4-bcf2-4b34f75ff55e@onelake.dfs.fabric.microsoft.com/ce87ddcd-3454-4b31-a8f6-c0f07c47c672/Tables/dbo/dimproducts"
)
df.printSchema()
print(f"Row count: {df.count()}")
df.show(5, truncate=False)
